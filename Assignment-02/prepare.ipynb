# %%
import pandas as pd
### Load the dataset
data=pd.read_csv('dataset/SMSSpamCollection',sep='\t',header=None)
### Rename the columns 
data.columns=['label','message']
### Map the labels to binary values
data['label']=data['label'].map({'ham':0,'spam':1})
data.to_csv("dataset/raw_data.csv", index=False)
print("\nraw_data.csv saved successfully!")
# Out:
# raw_data.csv saved successfully!

# %% [markdown]
# #### **Initialize Git & DVC**

# %%
pip install dvc

# %%
#### Initialize git 
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/Arnab Bera/Desktop/CMI/CMI/Applied-ML/AppliedMachineLearning-main/AppliedMachineLearning/Assignment-02/.git/

# %%
#### initialize DVC
# !dvc init
# Out:
# Initialized DVC repository.
#
# You can now commit the changes to git.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/treeverse/dvc>

# %% [markdown]
# #### **STEP-1: Create Train , Validation, Test Split (Version-1: random_state=42)**

# %%
from sklearn.model_selection import train_test_split
import os 
### First split: Train+Val and test
train_val, test = train_test_split(
    data,
    test_size=0.15,
    stratify=data["label"],
    random_state=42
)
### Second split: train and validation
train, val = train_test_split(
    train_val,
    test_size=0.1765,  # makes final 15%
    stratify=train_val["label"],
    random_state=42
)
train.to_csv("dataset/train.csv", index=False)
val.to_csv("dataset/validation.csv", index=False)
test.to_csv("dataset/test.csv", index=False)

print("Train shape:", train.shape)
print("Validation shape:", val.shape)
print("Test shape:", test.shape)
# Out:
# Train shape: (3900, 2)
# Validation shape: (836, 2)
# Test shape: (836, 2)

# %% [markdown]
# #### **PRINT DISTRIBUTION (VERSION-1)**

# %%
print("VERSION 1: Distribution \n")
for file in ["train.csv", "validation.csv", "test.csv"]:
    df = pd.read_csv(os.path.join("dataset", file))
    print(f"{file} distribution:")
    print(df["label"].value_counts(normalize=True))
    print("\n")
# Out:
# VERSION 1: Distribution
#
# train.csv distribution:
# label
# 0    0.865897
# 1    0.134103
# Name: proportion, dtype: float64
#
#
# validation.csv distribution:
# label
# 0    0.866029
# 1    0.133971
# Name: proportion, dtype: float64
#
#
# test.csv distribution:
# label
# 0    0.866029
# 1    0.133971
# Name: proportion, dtype: float64

# %% [markdown]
# #### **TRACK WITH DVC**

# %%
# !dvc add dataset/raw_data.csv
# !dvc add dataset/train.csv
# !dvc add dataset/validation.csv
# !dvc add dataset/test.csv
# Out:
# To track the changes with git, run:
#
# 	git add 'dataset\.gitignore' 'dataset\raw_data.csv.dvc'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# To track the changes with git, run:
#
# 	git add 'dataset\train.csv.dvc' 'dataset\.gitignore'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# To track the changes with git, run:
#
# 	git add 'dataset\validation.csv.dvc' 'dataset\.gitignore'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# To track the changes with git, run:
#
# 	git add 'dataset\test.csv.dvc' 'dataset\.gitignore'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph

# %% [markdown]
# #### **Commit DVC tracking**

# %%
# !git add dataset/*.dvc .gitignore
# !git commit -m "Track dataset with DVC"
# Out:
# fatal: pathspec '.gitignore' did not match any files
# [master 229afcf] Track dataset with DVC
#  7 files changed, 6 insertions(+), 11152 deletions(-)
#  create mode 100644 .dvc/.gitignore
#  create mode 100644 .dvc/config
#  create mode 100644 .dvcignore
#  delete mode 100644 dataset/raw_data.csv
#  delete mode 100644 dataset/test.csv
#  delete mode 100644 dataset/train.csv
#  delete mode 100644 dataset/validation.csv

# %% [markdown]
# #### **Push Data to DVC storage**

# %%
# !mkdir dvc_storage
# !dvc remote add -d local_remote dvc_storage
# !git add .dvc/config
# !git commit -m "Configure DVC local remote"
# !dvc push
# Out:
# Setting 'local_remote' as a default remote.
# [master 75cde20] Configure DVC local remote
#  1 file changed, 4 insertions(+)
# 4 files pushed

# %% [markdown]
# #### **Version 2 (Seed 123)**

# %%
from sklearn.model_selection import train_test_split
import os 
### First split: Train+Val and test
train_val, test = train_test_split(
    data,
    test_size=0.15,
    stratify=data["label"],
    random_state=12
)
### Second split: train and validation
train, val = train_test_split(
    train_val,
    test_size=0.1765,  # makes final 15%
    stratify=train_val["label"],
    random_state=42
)
train.to_csv("dataset/train.csv", index=False)
val.to_csv("dataset/validation.csv", index=False)
test.to_csv("dataset/test.csv", index=False)

print("Train shape:", train.shape)
print("Validation shape:", val.shape)
print("Test shape:", test.shape)
# Out:
# Train shape: (3900, 2)
# Validation shape: (836, 2)
# Test shape: (836, 2)

# %%
print("VERSION 1: Distribution \n")
for file in ["train.csv", "validation.csv", "test.csv"]:
    df = pd.read_csv(os.path.join("dataset", file))
    print(f"{file} distribution:")
    print(df["label"].value_counts(normalize=True))
    print("\n")
# Out:
# VERSION 1: Distribution
#
# train.csv distribution:
# label
# 0    0.865897
# 1    0.134103
# Name: proportion, dtype: float64
#
#
# validation.csv distribution:
# label
# 0    0.866029
# 1    0.133971
# Name: proportion, dtype: float64
#
#
# test.csv distribution:
# label
# 0    0.866029
# 1    0.133971
# Name: proportion, dtype: float64

# %% [markdown]
# #### **Track updated Version**

# %%
# !dvc add dataset/raw_data.csv
# !dvc add dataset/train.csv
# !dvc add dataset/validation.csv
# !dvc add dataset/test.csv
# Out:
# To track the changes with git, run:
#
# 	git add 'dataset\raw_data.csv.dvc'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# To track the changes with git, run:
#
# 	git add 'dataset\train.csv.dvc'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# To track the changes with git, run:
#
# 	git add 'dataset\validation.csv.dvc'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# To track the changes with git, run:
#
# 	git add 'dataset\test.csv.dvc'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph

# %%
# !git add dataset/train.csv.dvc
# !git add dataset/validation.csv.dvc
# !git add dataset/test.csv.dvc

# %%
# !git commit -m "Version 2: Updated random state for train-test split"
# Out:
# [master e9d3d18] Version 2: Updated random state for train-test split
#  3 files changed, 6 insertions(+), 6 deletions(-)

# %% [markdown]
# #### **Checkout the OLD Version**

# %%
# !git log --oneline
# Out:
# e9d3d18 Version 2: Updated random state for train-test split
# a5add0e Update train/val/test splits with new random state
# 75cde20 Configure DVC local remote
# 229afcf Track dataset with DVC
# 95c668b Initialize Git and DVC

# %%
# !git log
# Out:
# commit e9d3d18bc8db27b23328907a5e62c0f037f5d4a5
# Author: Arnab Bera <arnabbera24122002@gmail.com>
# Date:   Sun Feb 15 21:53:04 2026 +0530
#
#     Version 2: Updated random state for train-test split
#
# commit a5add0ecd0f875c3b40503a79678d8f0c1e327c7
# Author: Arnab Bera <arnabbera24122002@gmail.com>
# Date:   Sun Feb 15 21:51:53 2026 +0530
#
#     Update train/val/test splits with new random state
#
# commit 75cde20e43dea140ca538afd8662e8fa7e2eed66
# Author: Arnab Bera <arnabbera24122002@gmail.com>
# Date:   Sun Feb 15 21:47:45 2026 +0530
#
#     Configure DVC local remote
#
# commit 229afcf7c47007770a230147c66c86f973e4158b
# Author: Arnab Bera <arnabbera24122002@gmail.com>
# Date:   Sun Feb 15 21:46:18 2026 +0530
#
#     Track dataset with DVC
#
# commit 95c668b3125efce158473751348b83234753fad3
# Author: Arnab Bera <arnabbera24122002@gmail.com>
# Date:   Sun Feb 15 21:31:51 2026 +0530
#
#     Initialize Git and DVC

# %%
## Reload the files nd check the distribution again
train = pd.read_csv("dataset/train.csv")
val = pd.read_csv("dataset/validation.csv")     
print("VERSION 2: Distribution \n")
for file in ["train.csv", "validation.csv", "test.csv"]:
    df = pd.read_csv(os.path.join("dataset", file))
    print(f"{file} distribution:")
    print(df["label"].value_counts(normalize=True))
    print("\n")
# Out:
# VERSION 2: Distribution
#
# train.csv distribution:
# label
# 0    0.865897
# 1    0.134103
# Name: proportion, dtype: float64
#
#
# validation.csv distribution:
# label
# 0    0.866029
# 1    0.133971
# Name: proportion, dtype: float64
#
#
# test.csv distribution:
# label
# 0    0.866029
# 1    0.133971
# Name: proportion, dtype: float64
